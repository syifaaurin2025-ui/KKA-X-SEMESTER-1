# %% [markdown]
# <a href="https://colab.research.google.com/github/syifaaurin2025-ui/KKA-X-SEMESTER-1/blob/main/2_Tipe_Variabel_Syifa_AM_X_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Syifa Aurin Maghfiroh
#
# Kelas: X.8
#
# No. Absen: 35

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("syifaaurin.2025@gmail.com")
print("syifaaurin.2025@gmail.com")
print("syifaaurin.2025@gmail.com")
print("syifaaurin.2025@gmail.com")
# Out:
# syifaaurin.2025@gmail.con
# syifaaurin.2025@gmail.con
# syifaaurin.2025@gmail.con
# syifaaurin.2025@gmail.con

# %%
email_user_1 = "syifaaurin.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# syifaaurin.2025@gmail.com
# syifaaurin.2025@gmail.com
# syifaaurin.2025@gmail.com
# syifaaurin.2025@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
# Hanya boleh huruf, angka, underscore

nama siswa = "Azkaal Tifani"
# Out:
#   File "/tmp/ipython-input-171098574.py", line 3
#     nama siswa = "Azkaal Tifani"
#          ^
# SyntaxError: invalid syntax

# %%
namasiswa1 = "Azkaal Tifani"
nama_mahasiswa_1 = "Yoga Afgani"

print(namasiswa1)
print(nama_mahasiswa_1)
# Out:
# Azkaal Tifani
# Yoga Afgani

# %%
# Tidak boleh didahului angka

1_nama_guru = "Shinta Hanafia"

print(1_nama_guru)
# Out:
#   File "/tmp/ipython-input-2377730658.py", line 3
#     1_nama_guru = "Shinta Hanafia"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Sensitif terhadal kapital

tinggi_badan = 150

print(Tinggi_badan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3177799734.py in <cell line: 0>()
#       3 tinggi_badan = 150
#       4
# ----> 5 print(Tinggi_badan)
#
# NameError: name 'Tinggi_badan' is not defined

# %%
# Tidak Boleh dengan kata kunci python

class = "X.8"

print(class)
# Out:
#   File "/tmp/ipython-input-4428288.py", line 3
#     class = "X.8"
#           ^
# SyntaxError: invalid syntax

# %%
# Tidak Error tapi tidak descriptive

_ = "Farros Aleea"

print(_)

nama_mahasiswa_itb = "Farros Taulany"
print(nama_mahasiswa_itb)
# Out:
# Farros Aleea
# Farros Taulany

# %%
# contoh soal membuat variabel yang benar

nama_buah = "apel"
hargabuah = 1500
kasir_1 = "kareena"

print(nama_buah)
print(hargabuah)
print(kasir_1)
# Out:
# apel
# 1500
# kareena

# %% [markdown]
# #Assignment

# %%
#Single Assignment
harga_rinso = 10000

print(harga_rinso)
# Out:
# 10000

# %%
harga_molto = 30000
harga_pepsodent = 15000
harga_pocari = 10000

print(harga_molto)
print(harga_pepsodent)
print(harga_pocari)
# Out:
# 30000
# 15000
# 10000

# %%
#Multiple Assignment
harga_telur, harga_royco, harga_walls = 26000, 5000, 10000

print(harga_telur)
print(harga_royco)
print(harga_walls)
# Out:
# 26000
# 5000
# 10000

# %%
nama_siswa_1, nilai_uh_kka_1 = "Shinta Hanafia", 90

print(nama_siswa_1)
print(nilai_uh_kka_1)
# Out:
# Shinta Hanafia
# 90

# %%
nama_siswa_1, nilai_uh_kka_1, nama_ortu_1 = "Shinta Hanafia", 90, "Muhammad Abdullah"

print(nama_siswa_1)
print(nilai_uh_kka_1)
print(nama_ortu_1)
# Out:
# Shinta Hanafia
# 90
# Muhammad Abdullah

# %%
nilai_yoga = 100
nilai_farros = 100
nilai_lisaan = 100

# %%
nilai_yoga, nilai_farros, nilai_lisaan = 100, 100, 100

# %%
#Chain Assignment

nilai_yoga = nilai_farros = nilai_lisaan = 100

# %%
print(nilai_yoga, nilai_farros, nilai_lisaan)
# Out:
# 100 100 100

# %% [markdown]
# #Cara penggunaan operator di phyton

# %%
#Tanpa Variabel

print(9+3)
# Out:
# 12

# %%
print("9+3")
# Out:
# 9+3

# %%
print(sembilan plus tiga)
# Out:
#   File "/tmp/ipython-input-3845315770.py", line 1
#     print(sembilan plus tiga)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#operand disimpan ke variabel

buku_tulis_yoga = 9
buku_tulis_yogi = 3

print(buku_tulis_yoga + buku_tulis_yogi)
# Out:
# 12

# %%
#Hasil operasi disimpan ke variabel

total_buku_tulis = 9+3

print(total_buku_tulis)
# Out:
# 12

# %%
#Operand dan hasil operasi disimpan ke variabel

buku_tulis_yoga = 9
buku_tulis_yogi = 3
total_buku_tulis = buku_tulis_yoga + buku_tulis_yogi

print(total_buku_tulis)
# Out:
# 12

# %% [markdown]
# #Jenis Operator Aritmatika

# %%
#Penjumlahan

apel_shinta = 5
apel_aurin = 2

total_apel = apel_shinta + apel_aurin

print(total_apel)
# Out:
# 7

# %%
#pengurangan

apel_shinta = 5
apel_aurin = 2

selisih_apel = apel_shinta - apel_aurin

print(selisih_apel)
# Out:
# 3

# %%
#perkalian
jumlah_kardus_air_minum = 3
jumlah_botol_perkardus = 10

jumlah_botol_air_minum = jumlah_kardus_air_minum * jumlah_botol_perkardus

print(jumlah_botol_air_minum)
# Out:
# 30

# %%
#Pembagian
total_botol_air_minum = 30
jumlah_anak_yatim = 7

jumlah_botol_tiap_anak_yatim = total_botol_air_minum / jumlah_anak_yatim

print(jumlah_botol_tiap_anak_yatim)
# Out:
# 4.285714285714286

# %%
#pembagian bulat

total_botol_air_minum = 30
jumlah_anak_yatim = 7

jumlah_botol_tiap_anak_yatim = total_botol_air_minum // jumlah_anak_yatim

print(jumlah_botol_tiap_anak_yatim)
# Out:
# 4

# %%
#Sisa bagi

total_botol_air_minum = 30
jumlah_anak_yatim = 7

sisa_bagi_botol = total_botol_air_minum % jumlah_anak_yatim

print(sisa_bagi_botol)
# Out:
# 2

# %%
#perpangkatan

sisi = 6
luas_persegi = 6**2

print(luas_persegi)
# Out:
# 36

# %%
volume_kubus = 27
sisi= volume_kubus**(1/3)

print(sisi)
# Out:
# 3.0

# %%
sisi = 3
volume_kubus = sisi ** 3

print(volume_kubus)
# Out:
# 27

# %%
luas_persegi = 25
sisi = luas_persegi ** (1/2)

print(sisi)
# Out:
# 5.0

# %% [markdown]
# #LATIHAN SOAL

# %%
#tanpa variabel

print(24*3)
# Out:
# 72

# %%
#hasil perkalian

total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_perkardus = 24
jumlah_kardus = 3

print(banyak_botol_perkardus * jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_perkardus = 24
jumlah_kardus = 3

total_jumlah_botol = banyak_botol_perkardus * jumlah_kardus

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #LATIHAN SOAL ARITMATIKA

# %%
#penjumlahan

apel_dina = 8
apel_ibu = 5

total_apel = apel_dina + apel_ibu

print(total_apel)
# Out:
# 13

# %%
#pengurangan

total_mangga = 30
dijual = 12

total_mangga = total_mangga - dijual

print(total_mangga)
# Out:
# 18

# %%
#perkalian

meja_perkelas = 6
siswa = 4

total_siswa = meja_perkelas * siswa

print(total_siswa)
# Out:
# 24

# %%
#pembagian

jumlah_roti = 30
jumlah_anak = 4

total_roti = jumlah_roti / jumlah_anak

print(total_roti)
# Out:
# 7.5

# %%
#pembagian bulat & sisa bagi

jumlah_roti = 30
jumlah_anak = 4

total_roti = jumlah_roti // apel_ibu

sisa_bagi = jumlah_roti & apel_ibu

print(total_roti)
print(sisa_bagi)
# Out:
# 6
# 4

# %%
#sisa bagi

jumlah_donat = 25
jumlah_anak = 6

total_sisa_bagi = jumlah_donat % jumlah_anak

print(total_sisa_bagi)
# Out:
# 1

# %%
#perpangkatan

sisi = 7
luas_persegi = 7**2

print(luas_persegi)
# Out:
# 49

# %%
#akar kuadrat

luas_persegi = 81
sisi = luas_persegi ** (1/2)

print(sisi)
# Out:
# 9.0

# %%
#akar pangkat tiga

volume_kubus = 64
panjang_kubus = volume_kubus ** (1/3)

print(panjang_kubus)
# Out:
# 3.9999999999999996

# %% [markdown]
# #Jenis Jenis Tipe Variabel

# %%
a = 0
print(a)
type(a)
# Out:
# 0
# int

# %%
b = 0.0
print(b)
type(b)
# Out:
# 0.0
# float

# %%
c = "Hasyim"
print(c)
type(c)
# Out:
# Hasyim
# str

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3721722550.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %%
f = 9,9
print(f)
type(f)
# Out:
# (9, 9)
# tuple

# %%
type(8.1)
# Out:
# float

# %% [markdown]
# #Mengubah Tipe Variabel

# %%
x = 8
print(x)
type(x)
# Out:
# 8
# int

# %%
x = float(x)
print(x)
type(x)
# Out:
# 8.0
# float

# %%
z = 10
print(z)
type(z)
# Out:
# 10
# int

# %%
z = float(z)
print(z)
type(z)
# Out:
# 10.0
# float

# %%
k = True
print(k)
type(k)
# Out:
# True
# bool

# %%
k = int(k)
print(k)
type(k)
# Out:
# 1
# int

# %%
m = 2
print(m)
type(m)
# Out:
# 2
# int

# %%
m = bool(m)
print(m)
type(m)
# Out:
# True
# bool

# %%
n = 0.0
print(n)
type(n)
# Out:
# 0.0
# float

# %%
h = float(5)
print(h)
type(h)
# Out:
# 5.0
# float

# %% [markdown]
# #Operator perbandingan

# %%
print(6>=6)
# Out:
# True

# %%
print(8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print(8<10)
# Out:
# True

# %%
print(8>10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5<=5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print(7<1 or 2!=2)
# Out:
# False

# %%
print(not(0==1 and 1!=1))
# Out:
# True

# %%
print(not(5<=0 or 5<=10))
# Out:
# False
